# %% [markdown]
# # Segment 2: Activation Maximization
#
# *Contributed by Joyce Jiang*

# %%
# Load model and select target layer
import torch
import torchvision.models as models
import matplotlib.pyplot as plt

from lucent.optvis import render, param, objectives
from lucent.modelzoo import inceptionv1

device = "cuda" if torch.cuda.is_available() else "cpu"

model = inceptionv1(pretrained=True).to(device)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/16/7cm7dl9d6qn5nkchhjc1qtpr0000gn/T/ipykernel_5287/3827666235.py in <module>
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 from lucent.optvis import render, param, objectives
#       7 from lucent.modelzoo import inceptionv1
#       8
#
# ModuleNotFoundError: No module named 'lucent'

# %%
def neuron_objective(activations, channel):
    return activations[:, channel].mean()

# %%
# Pseudocode: Lucent-style parameterization
param = image_param(size=224)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/16/7cm7dl9d6qn5nkchhjc1qtpr0000gn/T/ipykernel_5287/1980336636.py in <module>
#       1 # Pseudocode: Lucent-style parameterization
# ----> 2 param = image_param(size=224)
#
# NameError: name 'image_param' is not defined
